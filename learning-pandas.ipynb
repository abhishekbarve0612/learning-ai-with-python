# %%
import pandas as pd

# %%
groceries = pd.Series(data=[30, 5, 'Yes', 'No'], index=['eggs', 'apples', 'milk', 'bread'])

print(groceries)
# Out:
# eggs       30
# apples      5
# milk      Yes
# bread      No
# dtype: object

# %%
print(groceries.shape)
# Out:
# (4,)

# %%
groceries.ndim
# Out:
# 1

# %%
groceries.size
# Out:
# 4

# %%
groceries.index
# Out:
# Index(['eggs', 'apples', 'milk', 'bread'], dtype='str')

# %%
groceries.values
# Out:
# array([30, 5, 'Yes', 'No'], dtype=object)

# %%
'banana' in groceries
# Out:
# False

# %%
'bread' in groceries
# Out:
# True

# %%
groceries['eggs']
# Out:
# 30

# %%
groceries[['milk', 'bread']]
# Out:
# milk     Yes
# bread     No
# dtype: object

# %%
groceries.iloc[0]
# Out:
# 30

# %%
groceries.iloc[-1]
# Out:
# 'No'

# %%
groceries.iloc[[1,2]]
# Out:
# apples      5
# milk      Yes
# dtype: object

# %%
groceries.loc[['eggs', 'apples']]
# Out:
# eggs      30
# apples     5
# dtype: object

# %%
groceries['eggs'] = 2
groceries
# Out:
# eggs        2
# apples      5
# milk      Yes
# bread      No
# dtype: object

# %%
groceries.drop('apples')
# Out:
# eggs       2
# milk     Yes
# bread     No
# dtype: object

# %%
groceries
# Out:
# eggs        2
# apples      5
# milk      Yes
# bread      No
# dtype: object

# %%
groceries.drop('apples', inplace=True)
groceries
# Out:
# eggs       2
# milk     Yes
# bread     No
# dtype: object

# %%
fruits = pd.Series(
    [10, 6, 6],
    ['apples', 'oranges', 'bananas']
)

fruits
# Out:
# apples     10
# oranges     6
# bananas     6
# dtype: int64

# %%
fruits + 2
# Out:
# apples     12
# oranges     8
# bananas     8
# dtype: int64

# %%
fruits - 3
# Out:
# apples     7
# oranges    3
# bananas    3
# dtype: int64

# %%
fruits * 3
# Out:
# apples     30
# oranges    18
# bananas    18
# dtype: int64

# %%
fruits / 2
# Out:
# apples     5.0
# oranges    3.0
# bananas    3.0
# dtype: float64

# %%
import numpy as np

# %%
np.sqrt(fruits)
# Out:
# apples     3.162278
# oranges    2.449490
# bananas    2.449490
# dtype: float64

# %%
np.power(fruits, 2)
# Out:
# apples     100
# oranges     36
# bananas     36
# dtype: int64

# %%
fruits['apples'] + 2
# Out:
# np.int64(12)

# %%
fruits.iloc[0] - 2
# Out:
# np.int64(8)

# %%
fruits[['apples', 'oranges']] * 2
# Out:
# apples     20
# oranges    12
# dtype: int64

# %%
fruits.loc[['apples', 'oranges']] / 2
# Out:
# apples     5.0
# oranges    3.0
# dtype: float64

# %%
items = {
    'Alice': pd.Series([40, 20, 40], index=['books', 'glasses', 'bike']),
    'Bob': pd.Series([245, 543, 23, 43], index=['bike', 'pants', 'watch', 'books'])
}

type(items)
# Out:
# dict

# %%
shopping_carts = pd.DataFrame(items)

shopping_carts
# Out:
#          Alice    Bob
# bike      40.0  245.0
# books     40.0   43.0
# glasses   20.0    NaN
# pants      NaN  543.0
# watch      NaN   23.0

# %%
data = {
    'Alice': pd.Series([40, 20, 40]),
    'Bob': pd.Series([245, 543, 23, 43])
}

df = pd.DataFrame(data)

df
# Out:
#    Alice  Bob
# 0   40.0  245
# 1   20.0  543
# 2   40.0   23
# 3    NaN   43

# %%
shopping_carts.index
# Out:
# Index(['bike', 'books', 'glasses', 'pants', 'watch'], dtype='str')

# %%
shopping_carts.columns
# Out:
# Index(['Alice', 'Bob'], dtype='str')

# %%
shopping_carts.values
# Out:
# array([[ 40., 245.],
#        [ 40.,  43.],
#        [ 20.,  nan],
#        [ nan, 543.],
#        [ nan,  23.]])

# %%
shopping_carts.shape
# Out:
# (5, 2)

# %%
shopping_carts.ndim
# Out:
# 2

# %%
shopping_carts.size
# Out:
# 10

# %%
bob_sc = pd.DataFrame(items, columns=['Bob'])

bob_sc
# Out:
#        Bob
# bike   245
# pants  543
# watch   23
# books   43

# %%
sel_sc = pd.DataFrame(items, index=['books', 'pants'])

sel_sc
# Out:
#        Alice  Bob
# books   40.0   43
# pants    NaN  543

# %%
data = pd.DataFrame({
    'Alice': [1, 2, 3],
    'Bob': [4, 5, 6],
})

data
# Out:
#    Alice  Bob
# 0      1    4
# 1      2    5
# 2      3    6

# %%
data = pd.DataFrame({
    'Alice': [1, 2, 3],
    'Bob': [4, 5, 6],
}, index=['one', 'two', 'three'])

data
# Out:
#        Alice  Bob
# one        1    4
# two        2    5
# three      3    6

# %%
items = [{'bikes': 20, 'pants': 30, 'watches': 35}, 
          {'watches': 10, 'glasses': 50, 'bikes': 15, 'pants':5}]
store_items = pd.DataFrame(items, index = ['store 1', 'store 2'])

store_items
# Out:
#          bikes  pants  watches  glasses
# store 1     20     30       35      NaN
# store 2     15      5       10     50.0

# %%
store_items[['bikes']]
# Out:
#          bikes
# store 1     20
# store 2     15

# %%
store_items[['bikes', 'watches']]
# Out:
#          bikes  watches
# store 1     20       35
# store 2     15       10

# %%
store_items.loc[['store 1']]
# Out:
#          bikes  pants  watches  glasses
# store 1     20     30       35      NaN

# %%
store_items['bikes']['store 1']
# Out:
# np.int64(20)

# %%
store_items['shirt'] = [15, 2]

# %%
store_items
# Out:
#          bikes  pants  watches  glasses  shirt
# store 1     20     30       35      NaN     15
# store 2     15      5       10     50.0      2

# %%
store_items['suits'] = store_items['shirt'] + store_items['pants']

# %%
store_items
# Out:
#          bikes  pants  watches  glasses  shirt  suits
# store 1     20     30       35      NaN     15     45
# store 2     15      5       10     50.0      2      7

# %%
new_items = [
    {
        'bikes': 20,
        'pants': 30,
        'watches': 35,
        'glasses': 41,
    }
]

new_store = pd.DataFrame(new_items, index=['store 3'])

# %%
store_items = pd.concat([store_items, new_store])

store_items
# Out:
#          bikes  pants  watches  glasses  shirt  suits
# store 1     20     30       35      NaN   15.0   45.0
# store 2     15      5       10     50.0    2.0    7.0
# store 3     20     30       35     41.0    NaN    NaN

# %%
store_items['new_watches'] = store_items['watches'][1:]

# %%
store_items
# Out:
#          bikes  pants  watches  glasses  shirt  suits  new_watches
# store 1     20     30       35      NaN   15.0   45.0          NaN
# store 2     15      5       10     50.0    2.0    7.0         10.0
# store 3     20     30       35     41.0    NaN    NaN         35.0

# %%
store_items.insert(5, 'shoes', [6, 5, 0])

store_items
# Out:
#          bikes  pants  watches  glasses  shirt  shoes  suits  new_watches
# store 1     20     30       35      NaN   15.0      6   45.0          NaN
# store 2     15      5       10     50.0    2.0      5    7.0         10.0
# store 3     20     30       35     41.0    NaN      0    NaN         35.0

# %%
store_items.pop('new_watches')
store_items
# Out:
#          bikes  pants  watches  glasses  shirt  shoes  suits
# store 1     20     30       35      NaN   15.0      6   45.0
# store 2     15      5       10     50.0    2.0      5    7.0
# store 3     20     30       35     41.0    NaN      0    NaN

# %%
store_items = store_items.drop(['watches', 'shoes'], axis=1)

# %%
store_items
# Out:
#          bikes  pants  glasses  shirt  suits
# store 1     20     30      NaN   15.0   45.0
# store 2     15      5     50.0    2.0    7.0
# store 3     20     30     41.0    NaN    NaN

# %%
store_items = store_items.drop(['store 1', 'store 2'], axis=0)

store_items
# Out:
#          bikes  pants  glasses  shirt  suits
# store 3     20     30     41.0    NaN    NaN

# %%
store_items = store_items.rename(columns={'bikes': 'hats'})
store_items
# Out:
#          hats  pants  glasses  shirt  suits
# store 3    20     30     41.0    NaN    NaN

# %%
store_items = store_items.rename(index={'store 3': 'last store'})

store_items
# Out:
#             hats  pants  glasses  shirt  suits
# last store    20     30     41.0    NaN    NaN

# %%
store_items = store_items.set_index('pants')

store_items
# Out:
#        hats  glasses  shirt  suits
# pants
# 30       20     41.0    NaN    NaN

# %%
# We create a list of Python dictionaries
items2 = [{'bikes': 20, 'pants': 30, 'watches': 35, 'shirts': 15, 'shoes':8, 'suits':45},
          {'watches': 10, 'glasses': 50, 'bikes': 15, 'pants':5, 'shirts': 2, 'shoes':5, 'suits':7},
          {'bikes': 20, 'pants': 30, 'watches': 35, 'glasses': 4, 'shoes':10}]

# We create a DataFrame  and provide the row index
store_items = pd.DataFrame(items2, index = ['store 1', 'store 2', 'store 3'])

# We display the DataFrame
print(store_items)
# Out:
#          bikes  pants  watches  shirts  shoes  suits  glasses
# store 1     20     30       35    15.0      8   45.0      NaN
# store 2     15      5       10     2.0      5    7.0     50.0
# store 3     20     30       35     NaN     10    NaN      4.0

# %%
x = store_items.isnull().sum().sum()
x
# Out:
# np.int64(3)

# %%
store_items.isnull()
# Out:
#          bikes  pants  watches  shirts  shoes  suits  glasses
# store 1  False  False    False   False  False  False     True
# store 2  False  False    False   False  False  False    False
# store 3  False  False    False    True  False   True    False

# %%
store_items.count()
# Out:
# bikes      3
# pants      3
# watches    3
# shirts     2
# shoes      3
# suits      2
# glasses    2
# dtype: int64

# %%
store_items.dropna(axis=0)
# Out:
#          bikes  pants  watches  shirts  shoes  suits  glasses
# store 2     15      5       10     2.0      5    7.0     50.0

# %%
store_items.dropna(axis=1)
# Out:
#          bikes  pants  watches  shoes
# store 1     20     30       35      8
# store 2     15      5       10      5
# store 3     20     30       35     10

# %%
store_items.fillna(0)
# Out:
#          bikes  pants  watches  shirts  shoes  suits  glasses
# store 1     20     30       35    15.0      8   45.0      0.0
# store 2     15      5       10     2.0      5    7.0     50.0
# store 3     20     30       35     0.0     10    0.0      4.0

# %%
store_items.ffill(axis=0)
# Out:
#          bikes  pants  watches  shirts  shoes  suits  glasses
# store 1     20     30       35    15.0      8   45.0      NaN
# store 2     15      5       10     2.0      5    7.0     50.0
# store 3     20     30       35     2.0     10    7.0      4.0

# %%
store_items.ffill(axis=1)
# Out:
#          bikes  pants  watches  shirts  shoes  suits  glasses
# store 1   20.0   30.0     35.0    15.0    8.0   45.0     45.0
# store 2   15.0    5.0     10.0     2.0    5.0    7.0     50.0
# store 3   20.0   30.0     35.0    35.0   10.0   10.0      4.0

# %%
store_items.bfill(axis=0)
# Out:
#          bikes  pants  watches  shirts  shoes  suits  glasses
# store 1     20     30       35    15.0      8   45.0     50.0
# store 2     15      5       10     2.0      5    7.0     50.0
# store 3     20     30       35     NaN     10    NaN      4.0

# %%
store_items.bfill(axis=1)
# Out:
#          bikes  pants  watches  shirts  shoes  suits  glasses
# store 1   20.0   30.0     35.0    15.0    8.0   45.0      NaN
# store 2   15.0    5.0     10.0     2.0    5.0    7.0     50.0
# store 3   20.0   30.0     35.0    10.0   10.0    4.0      4.0

# %%
store_items.interpolate(method='linear', axis=0)
# Out:
#          bikes  pants  watches  shirts  shoes  suits  glasses
# store 1     20     30       35    15.0      8   45.0      NaN
# store 2     15      5       10     2.0      5    7.0     50.0
# store 3     20     30       35     2.0     10    7.0      4.0

# %%
store_items.interpolate(method='linear', axis=1)
# Out:
#          bikes  pants  watches  shirts  shoes  suits  glasses
# store 1   20.0   30.0     35.0    15.0    8.0   45.0     45.0
# store 2   15.0    5.0     10.0     2.0    5.0    7.0     50.0
# store 3   20.0   30.0     35.0    22.5   10.0    7.0      4.0
